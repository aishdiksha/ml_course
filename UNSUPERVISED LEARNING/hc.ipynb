# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
import plotly.io as pio
pio.renderers.default = "kaggle"

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.rename(columns={
    'Annual Income (k$)':'Income',
    'Spending Score (1-100)':'Score'
},
inplace=True)

# %%
df
# Out:
#      CustomerID   Genre  Age  Income  Score
# 0             1    Male   19      15     39
# 1             2    Male   21      15     81
# 2             3  Female   20      16      6
# 3             4  Female   23      16     77
# 4             5  Female   31      17     40
# ..          ...     ...  ...     ...    ...
# 195         196  Female   35     120     79
# 196         197  Female   45     126     28
# 197         198    Male   32     126     74
# 198         199    Male   32     137     18
# 199         200    Male   30     137     83
#
# [200 rows x 5 columns]

# %%
X = df[['Age','Income','Score']]

# %%
import scipy.cluster.hierarchy as sch

# %%
dendro = ff.create_dendrogram(X,linkagefun=lambda x:sch.linkage(x,"ward")) 
dendro.update_layout({'width':1000,'height':800})
dendro.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2ad2416e-868a-41d1-826f-a83d803943ef" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ad2416e-868a-41d1-826f-a83d803943ef")) {                    Plotly.newPlot(                        "2ad2416e-868a-41d1-826f-a83d803943ef",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[15.0,15.0,25.0,25.0],"xaxis":"x","y":[0.0,4.123105625617661,4.123105625617661,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[5.0,5.0,20.0,20.0],"xaxis":"x","y":[0.0,15.198684153570664,15.198684153570664,4.123105625617661],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[45.0,45.0,55.0,55.0],"xaxis":"x","y":[0.0,1.7320508075688772,1.7320508075688772,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[65.0,65.0,75.0,75.0],"xaxis":"x","y":[0.0,2.8284271247461903,2.8284271247461903,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[50.0,50.0,70.0,70.0],"xaxis":"x","y":[1.7320508075688772,5.431390245600108,5.431390245600108,2.8284271247461903],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[35.0,35.0,60.0,60.0],"xaxis":"x","y":[0.0,6.655824516917495,6.655824516917495,5.431390245600108],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[105.0,105.0,115.0,115.0],"xaxis":"x","y":[0.0,6.082762530298219,6.082762530298219,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[95.0,95.0,110.0,110.0],"xaxis":"x","y":[0.0,6.855654600401044,6.855654600401044,6.082762530298219],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[85.0,85.0,102.5,102.5],"xaxis":"x","y":[0.0,13.546217184144066,13.546217184144066,6.855654600401044],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[47.5,47.5,93.75,93.75],"xaxis":"x","y":[6.655824516917495,19.71265808786042,19.71265808786042,13.546217184144066],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[145.0,145.0,155.0,155.0],"xaxis":"x","y":[0.0,7.280109889280518,7.280109889280518,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[135.0,135.0,150.0,150.0],"xaxis":"x","y":[0.0,8.18535277187245,8.18535277187245,7.280109889280518],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[125.0,125.0,142.5,142.5],"xaxis":"x","y":[0.0,12.16552506059644,12.16552506059644,8.18535277187245],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[165.0,165.0,175.0,175.0],"xaxis":"x","y":[0.0,7.810249675906654,7.810249675906654,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[185.0,185.0,195.0,195.0],"xaxis":"x","y":[0.0,7.874007874011811,7.874007874011811,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[170.0,170.0,190.0,190.0],"xaxis":"x","y":[7.810249675906654,16.140012391568973,16.140012391568973,7.874007874011811],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[133.75,133.75,180.0,180.0],"xaxis":"x","y":[12.16552506059644,25.695330315059188,25.695330315059188,16.140012391568973],"yaxis":"y","type":" ...

# %%
df = pd.read_csv('Wholesale customers data.csv')
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
import scipy.cluster.hierarchy as sch

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
scaled_data = StandardScaler().fit_transform(df)

# %%
plt.figure(figsize=(15,8))
sch.dendrogram(sch.linkage(scaled_data,"ward"))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model=AgglomerativeClustering(n_clusters=2)
df['groups'] = model.fit_predict(scaled_data)

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen  groups
# 0          1338       0
# 1          1776       0
# 2          7844       0
# 3          1788       1
# 4          5185       0
# ..          ...     ...
# 435        2204       1
# 436        2346       1
# 437        1867       0
# 438        2125       1
# 439          52       1
#
# [440 rows x 9 columns]

# %%
from sklearn.decomposition import PCA

# %%
scaled_data.shape
# Out:
# (440, 8)

# %%
pca = PCA(n_components=3)
reduced_data = pca.fit_transform(scaled_data)
reduced_data.shape
# Out:
# (440, 3)

# %%
import plotly.express as px

# %%
px.scatter_3d(x=reduced_data[:,0],y=reduced_data[:,1],z=reduced_data[:,2])
# Out:
# <div>                            <div id="0a9f29a4-301d-47bb-b4fc-4a2d4b4f02f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a9f29a4-301d-47bb-b4fc-4a2d4b4f02f5")) {                    Plotly.newPlot(                        "0a9f29a4-301d-47bb-b4fc-4a2d4b4f02f5",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.8439389283589437,1.062676449436471,1.2691405157256095,-1.0567823867244304,0.634030484153582,0.5301108983814712,0.3995602447177718,0.7911656497336048,-0.6638311308147969,2.1506847984088258,1.255993894576048,-0.16821061177295138,1.43985588122082,1.4069561102138235,1.3739599872296244,-1.0718152121562046,1.2580123337964584,-0.6185990128414308,0.8670934289838254,-0.48466679469792534,0.3315146865744456,-1.2544410791612721,-0.6957547065668521,4.397755901930425,1.625988083160122,0.5609214479872612,-1.2069806928097015,-1.2331191169